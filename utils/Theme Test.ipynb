# %%
from matplotlib.colors import ListedColormap
set1 = ["#FF6031", "#DA36E8", "#1531FF", "#36E8CF", "#73FF3B"]
set2 = ["#E3E34F", "#E63740", "#60B5D1", "#91D63C", "#FC7E00" ]

c = ListedColormap(set2)
for i in xrange(5):
    plot(random.random((6)),c = c(i), linewidth = 2 )

# %%
for i in xrange(5):
    plot(random.random((6)),c = c(i) )
